# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
def f1(x, p0, p1, p2, p3, p4, p5):
    return p0+p1*x+p2*(x**2)+p3*(x**3)+p4*(x**4)+p5*(x**5)
popt, pcov = curve_fit(f1, x4, y4)
plt.plot(x4,f1(x4, *popt),'r-',label='polynom1')
plt.grid(True)
plt.legend()
plt.show()
plt.plot(x4, y4, 'b-', label='data')
plt.grid(True)
plt.legend()
plt.show()

# %%
def f2(x, p0, p1, p2, p3, q1, q2):
    return (p0+p1*x+p2*(x**2)+p3*(x**3))/(1+q1*x+q2*(x**2))
popt1, pcov1 = curve_fit(f2, x4, y4)
plt.plot(x4,f2(x4, *popt1),'r-',label='polynom2')
plt.plot(x4, y4, 'b-', label='data')
plt.legend()
plt.grid(True)
plt.show()

# %%
xx = np.linspace(-4, 4, 100)
plt.plot(xx,f1(xx, *popt),'b-',label='polynom1')
plt.plot(xx,f2(xx, *popt1),'r-',label='polynom2')
plt.legend()
